# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("region_scores/enterocytes/SNC_LCT_study/SNC_LCT_study_effects_wcounts.tsv",sep="\t",index_col=0)

# %%
df.head()
# Out:
#    sequence_id  ntot        SNC  fold_0--logcount_preds  \
# 0            0     0        NaN                4.575580
# 1            1     1       ID_5                4.533258
# 2            2     1       ID_4                4.532566
# 3            3     2  ID_4_ID_5                4.492068
# 4            4     1       ID_3                4.675583
#
#    fold_0--log_counts_diff  fold_0--log_probs_diff_abs_sum  \
# 0                 0.000000                        0.000000
# 1                -0.042323                      -23.442638
# 2                -0.043015                      -31.702385
# 3                -0.083512                      -46.924232
# 4                 0.100003                       49.796432
#
#    fold_0--probs_jsd_diff  fold_1--logcount_preds  fold_1--log_counts_diff  \
# 0                0.000000                4.537943                 0.000000
# 1               -0.013893                4.489097                -0.048847
# 2               -0.026966                4.638884                 0.100941
# 3               -0.032666                4.595917                 0.057973
# 4                0.021422                4.747725                 0.209781
#
#    fold_1--log_probs_diff_abs_sum  ...  fold_3--log_probs_diff_abs_sum  \
# 0                        0.000000  ...                        0.000000
# 1                      -26.035683  ...                      -18.679300
# 2                       45.191223  ...                       41.347904
# 3                       39.500847  ...                       39.014385
# 4                       97.306900  ...                       36.802025
#
#    fold_3--probs_jsd_diff  fold_4--logcount_preds  fold_4--log_counts_diff  \
# 0                0.000000                4.123574                 0.000000
# 1               -0.012425                4.144676                 0.021102
# 2                0.030415                4.027804                -0.095770
# 3                0.031376                4.046685                -0.076890
# 4                0.020982                4.209989                 0.086414
#
#    fold_4--log_probs_diff_abs_sum  fold_4--probs_jsd_diff  \
# 0                        0.000000                0.000000
# 1                       20.634243                0.011479
# 2                      -68.233120               -0.036524
# 3                      -67.293200               -0.037925
# 4                       46.415882                0.019891
#
#    log_counts_diff_avg  logcount_preds_avg  log_probs_diff_abs_sum_avg  \
# 0             0.000000            4.760121                    0.000000
# 1            -0.035544            4.724577                  -17.886402
# 2            -0.016452            4.743670                  -10.440040
# 3            -0.052140            4.707980                  -21.976599
# 4             0.111174            4.871295                   53.549305
#
#    probs_jsd_diff_avg
# 0            0.000000
# 1           -0.010171
# 2           -0.003584
# 3           -0.006696
# 4            0.023229
#
# [5 rows x 27 columns]

# %%
sns.barplot(x='ntot',y='logcount_preds_avg',data=df)
# Out:
# <Axes: xlabel='ntot', ylabel='logcount_preds_avg'>

# %%
sns.boxplot(x='ntot',y='log_counts_diff_avg',data=df)
# Out:
# <Axes: xlabel='ntot', ylabel='log_counts_diff_avg'>

# %%
sns.boxplot(x='ntot',y='probs_jsd_diff_avg',data=df)
# Out:
# <Axes: xlabel='ntot', ylabel='probs_jsd_diff_avg'>

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df)
# Out:
# <Axes: xlabel='ntot', ylabel='log_probs_diff_abs_sum_avg'>

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df,color='darkgrey')
#plt.savefig("region_plots/enterocytes_SLC5A12_regions_SNC_study.pdf",dpi=350,bbox_inches='tight',pad_inches=0)
plt.show()
plt.close()

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df,color='darkgrey')
# Out:
# <Axes: xlabel='ntot', ylabel='log_probs_diff_abs_sum_avg'>

# %%
df_subset = df.loc[df['ntot'].isin([0,1,12])].copy()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df_subset = df.loc[df['ntot'].isin([1,6])].copy()

# %%
params = {'mathtext.default': 'regular' }          
plt.rcParams.update(params)

# %%
mpl.rcParams['pdf.fonttype'] = 42

# %%
sns.boxplot(x='ntot',y='log_counts_diff_avg',data=df_subset,color='darkgrey')
plt.xticks([0,1],['single SNC','Chimp'],fontsize=14)
plt.xlabel('')
plt.yticks(fontsize=14)
plt.ylabel('$log(counts_{seq})-log(counts_{WT})$',fontsize=14)
plt.savefig("region_plots/enterocytes_SNC_LCT_boxplot_1SNC_chimp_logcounts.pdf",bbox_inches='tight',pad_inches=0)
plt.show()
plt.close()

#plt.ylabel('log(counts)-log(countsWT)',fontsize=14)

# %%
sns.boxplot(x='ntot',y='log_counts_diff_avg',data=df,color='darkgrey')
plt.xticks([0,1,2,3,4,5,6],fontsize=14)
plt.xlabel('')
plt.yticks(fontsize=14)
plt.ylabel('$log(counts_{seq})-log(counts_{WT})$',fontsize=14)
plt.savefig("region_plots/enterocytes_SNC_LCT_boxplot_human_chimp_combinations_logcounts.pdf",bbox_inches='tight',pad_inches=0)
plt.show()
plt.close()

#plt.ylabel('log(counts)-log(countsWT)',fontsize=14)

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df_subset,color='darkgrey')
plt.xticks([0,1],['single SNC','Chimp'],fontsize=14)
plt.xlabel('')
plt.yticks(fontsize=14)
plt.ylabel('$log(probs_{seq})-log(probs_{WT})$',fontsize=14)
plt.savefig("region_plots/enterocytes_SNC_LCT_boxplot_1SNC_chimp_logprobs.pdf",bbox_inches='tight',pad_inches=0)
plt.show()
plt.close()

#plt.ylabel('log(counts)-log(countsWT)',fontsize=14)

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df,color='darkgrey')
plt.xticks([0,1,2,3,4,5,6],fontsize=14)
plt.xlabel('number of SNCs')
plt.yticks(fontsize=14)
plt.ylabel('$log(probs_{seq})-log(probs_{WT})$',fontsize=14)
plt.savefig("region_plots/enterocytes_SNC_LCT_boxplot_human_chimp_combinations_logprobs.pdf",bbox_inches='tight',pad_inches=0)
plt.show()
plt.close()

#plt.ylabel('log(counts)-log(countsWT)',fontsize=14)

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df_subset,color='darkgrey')
plt.xticks([0,1,2],['WT','single SNC','Chimp'],fontsize=14)
plt.xlabel('')
plt.yticks(fontsize=14)
plt.ylabel('log[probs')
# Out:
# (array([-60., -40., -20.,   0.,  20.,  40.,  60.]),
#  [Text(0, -60.0, '−60'),
#   Text(0, -40.0, '−40'),
#   Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60')])

# %%
# Out:
#       sequence_id  ntot                                                SNC  \
# 0               0     0                                                NaN
# 1               1     1                                              ID_11
# 2               2     1                                              ID_10
# 4               4     1                                               ID_9
# 8               8     1                                               ID_8
# 16             16     1                                               ID_7
# 32             32     1                                               ID_6
# 64             64     1                                               ID_5
# 128           128     1                                               ID_4
# 256           256     1                                               ID_3
# 512           512     1                                               ID_2
# 1024         1024     1                                               ID_1
# 2048         2048     1                                               ID_0
# 4095         4095    12  ID_0_ID_1_ID_2_ID_3_ID_4_ID_5_ID_6_ID_7_ID_8_I...
#
#       fold_0--logcount_preds  fold_0--log_counts_diff  \
# 0                   4.457171                 0.000000
# 1                   4.464490                 0.007319
# 2                   4.456106                -0.001065
# 4                   4.466213                 0.009042
# 8                   4.555971                 0.098800
# 16                  4.364115                -0.093056
# 32                  4.421598                -0.035573
# 64                  4.524185                 0.067014
# 128                 4.481096                 0.023925
# 256                 4.303655                -0.153516
# 512                 4.447229                -0.009942
# 1024                4.440093                -0.017077
# 2048                4.514466                 0.057295
# 4095                4.398662                -0.058509
#
#       fold_0--log_probs_diff_abs_sum  fold_0--probs_jsd_diff  \
# 0                           0.000000                0.000000
# 1                          16.094528                0.011625
# 2                         -10.502651               -0.008765
# 4                          16.770048                0.010715
# 8                          42.213370                0.024711
# 16                        -30.242088               -0.015173
# 32                        -23.139273               -0.013443
# 64                         26.847153                0.015856
# 128                        14.757581                0.009469
# 256                       -36.468925               -0.016049
# 512                       -21.951004               -0.012019
# 1024                      -10.631049               -0.006652
# 2048                       33.271600                0.016213
# 4095                      -64.702940               -0.039248
#
#       fold_1--logcount_preds  fold_1--log_counts_diff  \
# 0                   5.456890                 0.000000
# 1                   5.467889                 0.011000
# 2                   5.457402                 0.000512
# 4                   5.465212                 0.008323
# 8                   5.467295                 0.010406
# 16                  5.379069                -0.077821
# 32                  5.449759                -0.007131
# 64                  5.420448                -0.036442
# 128                 5.490591                 0.033701
# 256                 5.235290                -0.221600
# 512                 5.464892                 0.008002
# 1024                5.475184                 0.018295
# 2048                5.515752                 0.058863
# 4095                5.242625                -0.214265
#
#       fold_1--log_probs_diff_abs_sum  ...  fold_3--log_probs_diff_abs_sum  \
# 0                           0.000000  ...                        0.000000
# 1                          20.961733  ...                       16.146914
# 2                          11.030829  ...                       24.820713
# 4                          10.064274  ...                       15.307383
# 8                          15.489824  ...                       29.205723
# 16                        -43.235840  ...                      -75.999950
# 32                        -18.941320  ...                       35.044540
# 64                        -28.142372  ...                       32.132298
# 128                        18.221365  ...                       24.663364
# 256                      -102.444290  ...                      -14.915209
# 512                        19.100490  ...                       12.058765
# 1024                       21.409687  ...                       -9.852469
# 2048                       36.083687  ...                       32.004660
# 4095                     -115.425170  ...                       72.324770
#
#       fold_3--probs_jsd_diff  fold_4--logcount_preds  fold_4--log_counts_diff  \
# 0                   0.000000                4.442572                 0.000000
# 1                   0.013101                4.460148                 0.017577
# 2                   0.014921                4.447434                 0.004863
# 4                   0.008944                4.437748                -0.004823
# 8                   0.017625                4.446510                 0.003939
# 16                 -0.034245                4.364250                -0.078322
# 32                  0.016375                4.405420                -0.037151
# 64                  0.016740                4.443108                 0.000536
# 128                 0.011529                4.508122                 0.065550
# 256                -0.007166                4.340356                -0.102215
# 512                 0.006171                4.449275                 0.006703
# 1024               -0.005303                4.407027                -0.035545
# 2048                0.013401                4.489753                 0.047182
# 4095                0.036911                4.376234                -0.066337
#
#       fold_4--log_probs_diff_abs_sum  fold_4--probs_jsd_diff  \
# 0                           0.000000                0.000000
# 1                          19.465190                0.011744
# 2                          17.134104                0.014072
# 4                         -10.481470               -0.010267
# 8                          13.939693                0.015933
# 16                        -46.497875               -0.024126
# 32                        -15.785674               -0.011227
# 64                         19.131393                0.016429
# 128                        25.049522                0.012867
# 256                       -35.277214               -0.017453
# 512                        17.068869                0.010673
# 1024                      -14.144484               -0.007462
# 2048                       51.986088                0.025254
# 4095                      -65.962326               -0.039816
#
#       log_counts_diff_avg  log_probs_diff_abs_sum_avg  probs_jsd_diff_avg  \
# 0                0.000000                    0.000000            0.000000
# 1                0.009962                   17.796652            0.011871
# 2                0.000586                    5.839176            0.003852
# 4                0.007010                    8.623305            0.005947
# 8                0.051515                   24.338125            0.019757
# 16              -0.090820                  -48.236027           -0.024194
# 32              -0.005509                  -10.171308           -0.007305
# 64               0.030407                   16.270735            0.010575
# 128              0.027566                   13.818479            0.006709
# 256             -0.107467                  -43.599300           -0.020005
# 512             -0.002009                    1.453318            0.000701
# 1024             0.000593                    1.353994            0.000324
# 2048             0.042240                   37.015045            0.017267
# 4095            -0.052080                  -51.623997           -0.029802
#
#       logcount_preds_avg
# 0               4.829393
# 1               4.839354
# 2               4.829979
# 4               4.836403
# 8               4.880908
# 16              4.738573
# 32              4.823884
# 64              4.859800
# 128             4.856959
# 256             4.721926
# 512             4.827385
# 1024            4.829986
# 2048            4.871633
# 4095            4.777313
#
# [14 rows x 27 columns]

# %%
df.loc[df['ntot']==1].sort_values(by='log_probs_diff_abs_sum_avg')[['SNC','log_probs_diff_abs_sum_avg']]
# Out:
#         SNC  log_probs_diff_abs_sum_avg
# 16     ID_7                  -48.236027
# 256    ID_3                  -43.599300
# 32     ID_6                  -10.171308
# 1024   ID_1                    1.353994
# 512    ID_2                    1.453318
# 2     ID_10                    5.839176
# 4      ID_9                    8.623305
# 128    ID_4                   13.818479
# 64     ID_5                   16.270735
# 1     ID_11                   17.796652
# 8      ID_8                   24.338125
# 2048   ID_0                   37.015045

# %%
human_SNCs = pd.read_csv("extra_data/hg38_panTro6_SLC5A12i_divergent_site.tsv",sep="\t")
human_SNCs = human_SNCs.reset_index()
human_SNCs['ID'] = 'ID_'+human_SNCs['index'].astype('str')

# %%
human_SNCs
# Out:
#     index   #chr  hg38_coor(1-based) Hg38 panTro6     ID
# 0       0  chr11            26717833    T       C   ID_0
# 1       1  chr11            26717838    A       G   ID_1
# 2       2  chr11            26717896    C       G   ID_2
# 3       3  chr11            26717913    T       C   ID_3
# 4       4  chr11            26717997    G       A   ID_4
# 5       5  chr11            26718046    A       G   ID_5
# 6       6  chr11            26718052    G       A   ID_6
# 7       7  chr11            26718055    A       G   ID_7
# 8       8  chr11            26718082    A       C   ID_8
# 9       9  chr11            26718125    T       C   ID_9
# 10     10  chr11            26718160    C       A  ID_10
# 11     11  chr11            26718177    T       C  ID_11

# %%
sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.boxplot(x='ntot',y='log_probs_diff_abs_sum_avg',data=df)
#
# NameError: name 'sns' is not defined

# %%
df_limits = df.loc[df['ntot'].isin([0,12])]

# %%
sns.barplot(x='ntot',y='logcount_preds_avg',data=df_limits)
# Out:
# <Axes: xlabel='ntot', ylabel='logcount_preds_avg'>

# %%
sns.barplot(x='ntot',y='log_counts_diff_avg',data=df_limits)
# Out:
# <Axes: xlabel='ntot', ylabel='log_counts_diff_avg'>
